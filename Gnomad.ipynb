# %%
import numpy as np
import pandas as pd
import os 
import tqdm
import urllib

from Bio import SeqIO
import seaborn as sns
import matplotlib.pyplot as plt
from bioservices import UniProt

# %%
df_g = pd.read_csv('genes.csv')
genes = df_g['Gene'].tolist()

# %%
with open('genes.txt', 'w') as f:
    for item in genes:
        f.write("%s\n" % item)

# %%
gene_name = 'mb'

base_url = 'https://gnomad.broadinstitute.org/gene/' + gene_name + '?dataset=exac'

# %%
base_url
# Out:
# 'https://gnomad.broadinstitute.org/gene/mb?dataset=exac'

# %%
import lxml
import bs4
import requests as req
from bs4 import BeautifulSoup

# %%
def find_right_id(acc):

    #acc = 'P13380'
    url = "https://www.uniprot.org/uniprot/" + acc
    resp = req.get(url)
 
    soup = BeautifulSoup(resp.text, 'lxml')
 
    metadata = soup.title.parent
    flag_obsolete = False
    flag_obsolete2 = False
    flag_pdb = False
    protein_analogues_list = []
    protein_with_structure = []
    pdb_elem = 'None'
    k = 0

    for line in metadata:
        if 'var isObsolete = true' in str(line):
            flag_obsolete = True
            break

    data = soup.prettify().split('\n')

    if flag_obsolete:
        for i, line in enumerate(data):
            if 'this entry became obsolete' in str(line):
                flag_obsolete2 = True
                break

    if flag_obsolete2:            
        for k, line in enumerate(data[i+1:]):
            if '<a href="/uniprot/' in str(line):
                protein_analogues_list.append(str.strip(data[i+k+2]))
                #k += 1
                if '<p>' in str(line):
                    break    
                
    if len(protein_analogues_list) > 1:
        protein_analogues_list = protein_analogues_list[:-1]
    
    
    for j, acc in enumerate(protein_analogues_list):
        url = "https://www.uniprot.org/uniprot/" + acc 
        resp = req.get(url)
 
        soup = BeautifulSoup(resp.text, 'lxml')
        data2 = soup.prettify().split('\n')
    
        for line in data2:
        
            if 'class="pdb"' in str(line):
                flag_pdb = True
                break

        data2 = soup.prettify().split('\n')
        if flag_pdb:
            for line in data2:
                if 'structurePresent = true' in str(line):
                    protein_with_structure.append(acc)
    
    if len(protein_with_structure) > 0:
        pdb_elem = protein_with_structure[0]
    
    return pdb_elem

# %%
df_unpr = pd.read_csv("uniprot.csv")
df_unpr = df_unpr.drop(['Unnamed: 0'], axis=1)
df_unpr = df_unpr.set_index('Filename')

df = pd.read_csv("df.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df = df.set_index('Filename')

df = df.join(df_unpr)

uniprot_seqids = df['Uniprot_id'].tolist()

df_g = pd.read_csv('genes.csv')
uniprot_genes = df_g['Uniprot_id'].tolist()

df_new_id = pd.read_csv('genes_to_update.csv')
old_id_list = df_new_id['Uniprot_id_old'].tolist()
new_id_list = df_new_id['Uniprot_id_valid'].tolist()

# %%
#dict_fail = {}
#dict_succ = {}

for i, acc in tqdm.tqdm_notebook(enumerate(uniprot_seqids[10000:20000])):
    if acc not in uniprot_genes:
        try:
            pdb_elem = find_right_id(acc)
        except ChunkedEncodingError:
            print("Error: ", i)
        
        if pdb_elem == 'None':
            dict_fail[acc] = pdb_elem
        else:
            dict_succ[acc] = pdb_elem
# Out:
# C:\Users\alexh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
len(dict_succ)
# Out:
# 209

# %%
len(dict_fail)
# Out:
# 3864

# %%
df_ = pd.DataFrame(dict_succ.items(), columns=['Uniprot_id_old', 'Uniprot_id_valid'])
display(df_)

df_.to_csv('genes_to_update.csv')
# Out:
#     Uniprot_id_old Uniprot_id_valid
# 0           P24991           P0AEG4
# 1           P24930           P0C918
# 2           P06128           P0AG82
# 3           P09097           P0AES4
# 4           P06982           P0AES6
# ..             ...              ...
# 204         P65726           P9WI83
# 205         P62161           P0DP29
# 206         P0A4Y0           P9WQ35
# 207         P32132           P0DTT0
# 208         P10529           P0C1B3
#
# [209 rows x 2 columns]

# %%
dict_fail
# Out:
# {'P00718': 'None',
#  'P07378': 'None',
#  'P06492': 'None',
#  'P00969': 'None',
#  'P98119': 'None',
#  'P00327': 'None',
#  'Q51760': 'None',
#  'P10762': 'None',
#  'P23694': 'None',
#  'P16094': 'None',
#  'P25779': 'None',
#  'P24289': 'None',
#  'P05414': 'None',
#  'P56272': 'None',
#  'P48499': 'None',
#  'Q01693': 'None',
#  'Q03464': 'None',
#  'P15636': 'None',
#  'P28313': 'None',
#  'P28316': 'None',
#  'P07584': 'None',
#  'Q7SIH2': 'None',
#  'P00760': 'None',
#  'P16404': 'None',
#  'P21505': 'None',
#  '220253': 'None',
#  'P56588': 'None',
#  '708676': 'None',
#  'P38197': 'None',
#  '22948': 'None',
#  'P08515': 'None',
#  'Q26609': 'None',
#  'Q8K1Z5': 'None',
#  'P51541': 'None',
#  'P07229': 'None',
#  'S31776': 'None',
#  'Q28133': 'None',
#  'P23540': 'None',
#  'P08056': 'None',
#  'P00784': 'None',
#  'P02879': 'None',
#  'P14559': 'None',
#  'Q9PW35': 'None',
#  'P00798': 'None',
#  ':Z25878': 'None',
#  '8810': 'None',
#  'P04067': 'None',
#  '983524': 'None',
#  'P55915': 'None',
#  'P29600': 'None',
#  'P16184': 'None',
#  'P15555': 'None',
#  'Q27743': 'None',
#  'P00766': 'None',
#  'P46489': 'None',
#  'Q06535': 'None',
#  'P17571': 'None',
#  'P49347': 'None',
#  'P02866': 'None',
#  'P80561': 'None',
#  'P23904': 'None',
#  'P04936': 'None',
#  'P03692': 'None',
#  'P11922': 'None',
#  'Q94734': 'None',
#  'P80030': 'None',
#  'Q45670': 'None',
#  ':Q00017': 'None',
#  'P80022': 'None',
#  'P10802': 'None',
#  'P00588': 'None',
#  'Q58292': 'None',
#  'P29736': 'None',
#  'O81934': 'None',
#  'P17584': 'None',
#  'nown': 'None',
#  '1E1A': 'None',
#  '1E2D': 'None',
#  '1E2E': 'None',
#  '1E2F': 'None',
#  'P00692': 'None',
#  'Q9S3L6': 'None',
#  'P46076': 'None',
#  'Q9RHW0': 'None',
#  'O26253': 'None',
#  'O26255': 'None',
#  'Q27709': 'None',
#  'Q7SIG3': 'None',
#  'P39042': 'None',
#  'O51923': 'None',
#  'Q26241': 'None',
#  'Q7SIG1': 'None',
#  'Q95182': 'None',
#  '44429': 'None',
#  'P04119': 'None',
#  'P10822': 'None',
#  'Q58206': 'None',
#  '199928': 'None',
#  '24880': 'None',
#  'Q08169': 'None',
#  'P69059': 'None',
#  'P31670': 'None',
#  'P56276': 'None',
#  'P45850': 'None',
#  'P00761': 'None',
#  'Q41159': 'None',
#  'P93324': 'None',
#  'O24529': 'None',
#  'P19424': 'None',
#  'Q7SIF6': 'None',
#  'Q8U3I1': 'None',
#  'Q59401': 'None',
#  '591902': 'None',
#  'P00717': 'None',
#  'P02240': 'None',
#  'P12257': 'None',
#  'P23339': 'None',
#  'Q46220': 'None',
#  'P09989': 'None',
#  'Q09431': 'None',
#  'P83218': 'None',
#  'Q56148': 'None',
#  'P24146': 'None',
#  'P46088': 'None',
#  'Q9WXN1': 'None',
#  'P56410': 'None',
#  'P14262': 'None',
#  '1GZC': 'None',
#  '1H07': 'None',
#  '1H08': 'None',
#  '1H1X': 'None',
#  '1H3W': 'None',
#  'P81637': 'None',
#  'P40943': 'None',
#  'P35031': 'None',
#  '1HJQ': 'None',
#  'P80017': 'None',
#  '501756': 'None',
#  'P23472': 'None',
#  'O29562': 'None',
#  'Q76353': 'None',
#  'P03315': 'None',
#  '220207': 'None',
#  '2007368': 'None',
#  'P34179': 'None',
#  'P02789': 'None',
#  'P73797': 'None',
#  'P14725': 'None',
#  'Q8ZUR7': 'None',
#  'O58727': 'None',
#  'O58346': 'None',
#  'Q7SID4': 'None',
#  'O80323': 'None',
#  'P18891': 'None',
#  'Q84CU4': 'None',
#  'P60994': 'None',
#  'O50082': 'None',
#  'Q8L3C8': 'None',
#  'Q9UVD4': 'None',
#  'Q9URD0': 'None',
#  'P44882': 'None',
#  'P84143': 'None',
#  'Q9WZS0': 'None',
#  'Q9WZD5': 'None',
#  '778709': 'None',
#  'Q47450': 'None',
#  'Q9HFV6': 'None',
#  'P56634': 'None',
#  'Q41736': 'None',
#  'Q9U8W8': 'None',
#  '75124': 'None',
#  'O04147': 'None',
#  'Q9X0M3': 'None',
#  '3701524': 'None',
#  '092089': 'None',
#  'Q9RP27': 'None',
#  'O97389': 'None',
#  'Q53464': 'None',
#  'Q7SIC1': 'None',
#  '004217': 'None',
#  'Q8U3L0': 'None',
#  'Q9WYN0': 'None',
#  'P11818': 'None',
#  'P12473': 'None',
#  'S43413': 'None',
#  'O57413': 'None',
#  'P03316': 'None',
#  'P09464': 'None',
#  'Q967M2': 'None',
#  'P12823': 'None',
#  'Q03243': 'None',
#  'P00733': 'None',
#  'P46925': 'None',
#  'Q59232': 'None',
#  'O67517': 'None',
#  '502809': 'None',
#  '9526603': 'None',
#  'P24476': 'None',
#  'O31410': 'None',
#  'P02883': 'None',
#  'Q44534': 'None',
#  'P05045': 'None',
#  '590454': 'None',
#  '3337128': 'None',
#  'Q9AGH8': 'None',
#  'Q8AV11': 'None',
#  'P10056': 'None',
#  'Q9X1H9': 'None',
#  '8274847': 'None',
#  'O33199': 'None',
#  '7063801': 'None',
#  'P83690': 'None',
#  'P09177': 'None',
#  'P17989': 'None',
#  'P83721': 'None',
#  'O24970': 'None',
#  'Q8IEU2': 'None',
#  '6076818': 'None',
#  'Q08884': 'None',
#  'P83512': 'None',
#  'O13998': 'None',
#  'Q9HIT9': 'None',
#  'P22851': 'None',
#  'Q04299': 'None',
#  'P83787': 'None',
#  'Q8TZN6': 'None',
#  'Q46961': 'None',
#  'Q9HIA7': 'None',
#  'Q9RV46': 'None',
#  'O76745': 'None',
#  'Q9X0G9': 'None',
#  'Q9X0P2': 'None',
#  'Q9X1V6': 'None',
#  'Q9WZX8': 'None',
#  'Q9X033': 'None',
#  'Q9WZK7': 'None',
#  'Q9X0Q3': 'None',
#  'Q9WY13': 'None',
#  'P93343': 'None',
#  'Q9KZR7': 'None',
#  'Q9ADS9': 'None',
#  'Q9NE49': 'None',
#  'Q9I8X1': 'None',
#  'P22337': 'None',
#  'Q8DCA6': 'None',
#  '1321072': 'None',
#  'Q9WXY0': 'None',
#  'Q9EXR9': 'None',
#  '5923454': 'None',
#  'O29759': 'None',
#  'P56252': 'None',
#  'Q8P2Q3': 'None',
#  'P02853': 'None',
#  'Q7SIG4': 'None',
#  '491795': 'None',
#  'P35049': 'None',
#  'Q9X0G1': 'None',
#  'P81536': 'None',
#  'Q9X264': 'None',
#  'P90613': 'None',
#  '02938': 'None',
#  'Q9HIB8': 'None',
#  'P47273': 'None',
#  '9568104': 'None',
#  'Q27679': 'None',
#  'P04509': 'None',
#  'Q96590': 'None',
#  '1QNX': 'None',
#  '299568': 'None',
#  'P40881': 'None',
#  'Q27198': 'None',
#  'P91020': 'None',
#  'Q8NW41': 'None',
#  '55661': 'None',
#  'O66665': 'None',
#  'Q9GQG7': 'None',
#  'Q9L6G5': 'None',
#  'P83667': 'None',
#  'P03300': 'None',
#  'P60623': 'None',
#  'P07797': 'None',
#  'Q6STF1': 'None',
#  'O53240': 'None',
#  '225975': 'None',
#  'Q9HII6': 'None',
#  'Q54324': 'None',
#  'Q9I4D4': 'None',
#  '3097522': 'None',
#  '5676604': 'None',
#  'Q8UAC1': 'None',
#  'Q8I4Y0': 'None',
#  'Q81L49': 'None',
#  'P84134': 'None',
#  '1219717': 'None',
#  'Q9K2L5': 'None',
#  'P15369': 'None',
#  'P74325': 'None',
#  'P56839': 'None',
#  'Q9R381': 'None',
#  'P84135': 'None',
#  '842445': 'None',
#  '0560072': 'None',
#  'Q82ZQ3': 'None',
#  'P14754': 'None',
#  'P84136': 'None',
#  'P84146': 'None',
#  'Q8U2E3': 'None',
#  'Q9RVK2': 'None',
#  '5281089': 'None',
#  'P07164': 'None',
#  'P52700': 'None',
#  '8837130': 'None',
#  'Q18946': 'None',
#  'Q8I3X4': 'None',
#  '7576792': 'None',
#  'P07268': 'None',
#  'P29599': 'None',
#  'P22629': 'None',
#  'P14336': 'None',
#  'O29280': 'None',
#  '580816': 'None',
#  'Q58588': 'None',
#  'P75429': 'None',
#  'O61793': 'None',
#  'P41365': 'None',
#  'P75455': 'None',
#  'Q90W54': 'None',
#  '6397630': 'None',
#  'P27914': 'None',
#  'P19515': 'None',
#  'P04072': 'None',
#  'P09943': 'None',
#  'Q27084': 'None',
#  'P04789': 'None',
#  'Q9YE16': 'None',
#  'Q99IU3': 'None',
#  'Q5SKJ3': 'None',
#  'Q08210': 'None',
#  '937361': 'None',
#  '4223562': 'None',
#  'P61914': 'None',
#  'Q9HIW7': 'None',
#  'Q9QCE4': 'None',
#  'P75430': 'None',
#  '1U9C': 'None',
#  '8272': 'None',
#  'Q5SJI0': 'None',
#  'Q9FXT4': 'None',
#  'Q7SIA0': 'None',
#  'P10186': 'None',
#  'Q8GEB3': 'None',
#  'P83702': 'None',
#  'O59595': 'None',
#  'Q975V5': 'None',
#  '8436805': 'None',
#  'Q9M7R2': 'None',
#  'Q9Y092': 'None',
#  '1US5': 'None',
#  'O58335': 'None',
#  '0850540': 'None',
#  'Q75WK2': 'None',
#  'O59257': 'None',
#  'O57758': 'None',
#  'Q9X1M1': 'None',
#  'Q7SI98': 'None',
#  'Q53WB3': 'None',
#  'O59580': 'None',
#  '5978324': 'None',
#  'O57770': 'None',
#  'Q746L8': 'None',
#  'O57975': 'None',
#  'Q6USC4': 'None',
#  'O57823': 'None',
#  'Q5SLE6': 'None',
#  'P26697': 'None',
#  'O58104': 'None',
#  'Q9WXV1': 'None',
#  'Q9X0D8': 'None',
#  'O28751': 'None',
#  'Q9KPK1': 'None',
#  'Q9ABV9': 'None',
#  'Q8YWS4': 'None',
#  'Q8YY48': 'None',
#  'Q9WZL1': 'None',
#  'Q9X1L2': 'None',
#  'Q9X274': 'None',
#  'Q8U3S5': 'None',
#  'Q9WYP6': 'None',
#  'Q9X1J4': 'None',
#  'Q9X1S2': 'None',
#  'Q9WZI2': 'None',
#  'O30133': 'None',
#  'Q8A1L2': 'None',
#  'Q9WYA0': 'None',
#  'Q9WZ14': 'None',
#  'Q9X1W6': 'None',
#  'O77206': 'None',
#  '9375004': 'None',
#  'Q97QP1': 'None',
#  '5644301': 'None',
#  '1W3O': 'None',
#  '1W3P': 'None',
#  '1W3Q': 'None',
#  'Q9RW27': 'None',
#  'Q9HUY3': 'None',
#  'O28590': 'None',
#  'O28951': 'None',
#  '1W9X': 'None',
#  'O52806': 'None',
#  'P15465': 'None',
#  'P82186': 'None',
#  'P15480': 'None',
#  'Q5SKH2': 'None',
#  '1280333': 'None',
#  'Q5SIB2': 'None',
#  'Q72LK7': 'None',
#  '5981580': 'None',
#  '5528903': 'None',
#  '857800': 'None',
#  'P20165': 'None',
#  '1WP5': 'None',
#  'P19571': 'None',
#  'O59452': 'None',
#  '5772310': 'None',
#  'Q9V2W5': 'None',
#  '4601697': 'None',
#  'Q9KB30': 'None',
#  '5614668': 'None',
#  'P83815': 'None',
#  'Q8JI39': 'None',
#  'O58261': 'None',
#  '4590908': 'None',
#  'Q53W84': 'None',
#  'O57946': 'None',
#  'Q53W82': 'None',
#  '7506672': 'None',
#  'Q9EB06': 'None',
#  'Q7M422': 'None',
#  'O58216': 'None',
#  'Q7M421': 'None',
#  'Q81HJ5': 'None',
#  '1X9G': 'None',
#  '1X9Q': 'None',
#  'Q9U6Y4': 'None',
#  '1067037': 'None',
#  '1XDW': 'None',
#  'Q949P3': 'None',
#  'Q9AAV3': 'None',
#  'Q8U1K9': 'None',
#  'Q816R4': 'None',
#  'Q8YSC4': 'None',
#  '1XJC': 'None',
#  'Q8KCB6': 'None',
#  '5643666': 'None',
#  'Q9KQU9': 'None',
#  'P48793': 'None',
#  '8629493': 'None',
#  'Q8ZVK6': 'None',
#  'P03303': 'None',
#  'P12916': 'None',
#  '4125563': 'None',
#  '1XTD': 'None',
#  'Q4Q7M2': 'None',
#  '1XWM': 'None',
#  '9913222': 'None',
#  '9484066': 'None',
#  'Q9HVP2': 'None',
#  '0840149': 'None',
#  '501761': 'None',
#  'Q4Q7A6': 'None',
#  'P72583': 'None',
#  '8858109': 'None',
#  '9235916': 'None',
#  'O28724': 'None',
#  'O28835': 'None',
#  'Q97GJ5': 'None',
#  'Q9KQN0': 'None',
#  'Q7VXW9': 'None',
#  'P14080': 'None',
#  'Q9HJW1': 'None',
#  'Q8U4C0': 'None',
#  'Q9KS51': 'None',
#  'Q8U046': 'None',
#  'Q97Q24': 'None',
#  'Q49434': 'None',
#  'O67322': 'None',
#  '8769986': 'None',
#  'P54958': 'None',
#  'Q8WS26': 'None',
#  '0420960': 'None',
#  '388165': 'None',
#  'P19901': 'None',
#  '657424': 'None',
#  'Q939N4': 'None',
#  'Q8A090': 'None',
#  'Q5SL73': 'None',
#  'O28840': 'None',
#  'Q8Y8Q1': 'None',
#  '458856': 'None',
#  'Q99ZW4': 'None',
#  'Q9HJ28': 'None',
#  'P96830': 'None',
#  'Q81EW9': 'None',
#  'Q839J6': 'None',
#  'Q4D3U8': 'None',
#  'Q9KQJ1': 'None',
#  'O29883': 'None',
#  'Q9SLV5': 'None',
#  '428731': 'None',
#  'Q9HYR3': 'None',
#  '1Z37': 'None',
#  '78489': 'None',
#  'O22322': 'None',
#  'Q97XQ5': 'None',
#  'Q8I2M1': 'None',
#  'Q837R1': 'None',
#  'Q9I4A4': 'None',
#  'Q9X0C0': 'None',
#  'Q7RSH5': 'None',
#  'Q3Y185': 'None',
#  '1ZB6': 'None',
#  'Q87HD3': 'None',
#  'Q7MVG4': 'None',
#  'Q8UC50': 'None',
#  'Q4R2T2': 'None',
#  '8976895': 'None',
#  'O28262': 'None',
#  '8859327': 'None',
#  'Q7WLM8': 'None',
#  'Q9YEQ6': 'None',
#  'Q81H03': 'None',
#  '1499392': 'None',
#  '929401': 'None',
#  '1540575': 'None',
#  'Q9I509': 'None',
#  'O30200': 'None',
#  'Q9LZX1': 'None',
#  '9349708': 'None',
#  'Q9EB08': 'None',
#  'Q4DSA0': 'None',
#  'O64527': 'None',
#  '8375658': 'None',
#  'Q8ZJX7': 'None',
#  'Q9U6Y6': 'None',
#  '0583821': 'None',
#  'P13901': 'None',
#  'Q8DQK6': 'None',
#  '54516': 'None',
#  'P81461': 'None',
#  'P56271': 'None',
#  'Q57622': 'None',
#  'Q97T51': 'None',
#  'P50694': 'None',
#  '47144': 'None',
#  'P09872': 'None',
#  'Q8NXQ8': 'None',
#  '5459176': 'None',
#  '0834870': 'None',
#  'Q8NX77': 'None',
#  'Q7MW33': 'None',
#  'P06026': 'None',
#  'Q7RPE4': 'None',
#  'Q4Q067': 'None',
#  'P00799': 'None',
#  'P49370': 'None',
#  'O24984': 'None',
#  '1853263': 'None',
#  'Q7R866': 'None',
#  'Q8UC14': 'None',
#  '2AYV': 'None',
#  '5644283': 'None',
#  'Q9I476': 'None',
#  '4972717': 'None',
#  'Q58193': 'None',
#  '3623011': 'None',
#  'O29285': 'None',
#  'O29141': 'None',
#  'Q4QH86': 'None',
#  'Q7RRM6': 'None',
#  'Q8DUW5': 'None',
#  'P84786': 'None',
#  '0697070': 'None',
#  '0842522': 'None',
#  'P23951': 'None',
#  '1095422': 'None',
#  'Q98325': 'None',
#  'Q7RB63': 'None',
#  'Q5ZZB6': 'None',
#  'Q9K6P2': 'None',
#  'Q7WK92': 'None',
#  'Q94KL8': 'None',
#  '2BGQ': 'None',
#  'P96398': 'None',
#  'Q7YXK2': 'None',
#  'Q9U0E8': 'None',
#  'O12287': 'None',
#  'P03606': 'None',
#  'P0C6U8': 'None',
#  'P16883': 'None',
#  'Q8WPJ2': 'None',
#  'Q6Q0L5': 'None',
#  '2C2A': 'None',
#  'Q9RWF4': 'None',
#  'Q57849': 'None',
#  'Q15KI8': 'None',
#  'P30113': 'None',
#  'P50477': 'None',
#  'Q9PMK9': 'None',
#  'Q03161': 'None',
#  'Q26548': 'None',
#  '2CMU': 'None',
#  '6419348': 'None',
#  'Q5SHI0': 'None',
#  '5SH33': 'None',
#  'Q198W5': 'None',
#  'Q5SKQ0': 'None',
#  'Q5SJF5': 'None',
#  'Q5SLC3': 'None',
#  'Q5SMG9': 'None',
#  'Q9YC08': 'None',
#  '5981178': 'None',
#  '5981537': 'None',
#  '7159431': 'None',
#  'Q5SH92': 'None',
#  '5920953': 'None',
#  '2490553': 'None',
#  '0018527': 'None',
#  '6766348': 'None',
#  'O57933': 'None',
#  'Q5SXE6': 'None',
#  'Q4W9V8': 'None',
#  '7806671': 'None',
#  'Q8J309': 'None',
#  '381269': 'None',
#  '2782169': 'None',
#  '355698': 'None',
#  '912516': 'None',
#  'O82839': 'None',
#  '1225284': 'None',
#  '07472': 'None',
#  'P36186': 'None',
#  'Q5SLW4': 'None',
#  'Q5SJQ7': 'None',
#  'Q7W0A0': 'None',
#  'Q86202': 'None',
#  'P58502': 'None',
#  'P95276': 'None',
#  'O59282': 'None',
#  'Q972W6': 'None',
#  'O59046': 'None',
#  'P13744': 'None',
#  'P16049': 'None',
#  'Q5SI78': 'None',
#  'Q5L3S8': 'None',
#  'P29563': 'None',
#  'Q5NTZ0': 'None',
#  'Q59014': 'None',
#  'P43316': 'None',
#  'Q974B8': 'None',
#  'Q8A611': 'None',
#  'Q9X056': 'None',
#  'Q87UR7': 'None',
#  'B2J9B4': 'None',
#  'Q6FF54': 'None',
#  'Q9X0A5': 'None',
#  '5606134': 'None',
#  '949912': 'None',
#  '2362414': 'None',
#  '5805717': 'None',
#  '2018064': 'None',
#  'Q830Y8': 'None',
#  '5807254': 'None',
#  'O61446': 'None',
#  'Q8IJH3': 'None',
#  'Q4UVI8': 'None',
#  '6803622': 'None',
#  '1497664': 'None',
#  '5598202': 'None',
#  'Q9KQV9': 'None',
#  '981552': 'None',
#  'P14070': 'None',
#  '949246': 'None',
#  '7739162': 'None',
#  'Q8A8B0': 'None',
#  '9340391': 'None',
#  '981064': 'None',
#  'Q9PI85': 'None',
#  '4972282': 'None',
#  '9648919': 'None',
#  '3880191': 'None',
#  '8557781': 'None',
#  '258020': 'None',
#  'P42088': 'None',
#  '6924206': 'None',
#  '981496': 'None',
#  '982422': 'None',
#  '5459167': 'None',
#  '636202': 'None',
#  '9896827': 'None',
#  '5609854': 'None',
#  'Q9HKL4': 'None',
#  'Q8UJ27': 'None',
#  'Q8UCP8': 'None',
#  '948014': 'None',
#  '980655': 'None',
#  '3613125': 'None',
#  'B0RM26': 'None',
#  '5598548': 'None',
#  'Q9X0D9': 'None',
#  '1656605': 'None',
#  '1322346': 'None',
#  'Q9HXQ8': 'None',
#  'Q83883': 'None',
#  'O29889': 'None',
#  '378782': 'None',
#  '87742': 'None',
#  '2G1U': 'None',
#  'Q6NJA6': 'None',
#  'Q7CXI0': 'None',
#  '4647276': 'None',
#  '24360': 'None',
#  '2313907': 'None',
#  '967670': 'None',
#  '2G5X': 'None',
#  'Q5F581': 'None',
#  'Q0S9X7': 'None',
#  '5020677': 'None',
#  '7738610': 'None',
#  '0517852': 'None',
#  'Q7MAW7': 'None',
#  '0517402': 'None',
#  'Q9I2Q9': 'None',
#  '5621447': 'None',
#  '6199590': 'None',
#  'Q7D0W3': 'None',
#  '4149875': 'None',
#  'Q9I4V0': 'None',
#  '0199': 'None',
#  'Q9K0T5': 'None',
#  'Q9WZM9': 'None',
#  '4971716': 'None',
#  '1055590': 'None',
#  'P33160': 'None',
#  'P83052': 'None',
#  '7814381': 'None',
#  'P44941': 'None',
#  '929802': 'None',
#  '1594340': 'None',
#  'Q6NEA9': 'None',
#  '3622042': 'None',
#  'Q9KUL5': 'None',
#  '4973654': 'None',
#  '2GUU': 'None',
#  '0640422': 'None',
#  '9338526': 'None',
#  '4396991': 'None',
#  'C6DXJ2': 'None',
#  '2896483': 'None',
#  'Q4Y719': 'None',
#  'Q86SB2': 'None',
#  'Q5SK45': 'None',
#  '2H5P': 'None',
#  '2H5Q': 'None',
#  '2H5R': 'None',
#  '2H5U': 'None',
#  'Q6VA80': 'None',
#  'Q8UBX7': 'None',
#  'Q9I5E5': 'None',
#  'Q9KUP8': 'None',
#  'Q8EIU4': 'None',
#  'Q9A395': 'None',
#  'Q3M7N3': 'None',
#  'Q8KBS5': 'None',
#  'Q88YA8': 'None',
#  'Q3I0Y8': 'None',
#  'Q2ZZ07': 'None',
#  'D0VWU8': 'None',
#  'Q88R33': 'None',
#  'P07435': 'None',
#  'Q8UD29': 'None',
#  'Q8U6Y1': 'None',
#  'Q9X0V1': 'None',
#  'O59346': 'None',
#  'Q01594': 'None',
#  'Q4CFD1': 'None',
#  'Q9U6Y3': 'None',
#  'Q7CX01': 'None',
#  'Q8UBW2': 'None',
#  'Q0SB06': 'None',
#  'Q9KFA8': 'None',
#  'P27282': 'None',
#  'Q57K43': 'None',
#  'Q7V4A7': 'None',
#  'Q8P3K2': 'None',
#  'Q9X2E8': 'None',
#  'Q8CJS4': 'None',
#  'Q6D668': 'None',
#  'Q7PP01': 'None',
#  'P12670': 'None',
#  'Q816V9': 'None',
#  'O28741': 'None',
#  'Q7MW92': 'None',
#  'Q97VZ7': 'None',
#  'Q7MWA6': 'None',
#  'O25234': 'None',
#  'Q4FPZ7': 'None',
#  'Q9XA31': 'None',
#  'Q926X2': 'None',
#  'Q837K0': 'None',
#  'P29557': 'None',
#  'Q8X123': 'None',
#  'Q4VPP2': 'None',
#  'Q2FEH1': 'None',
#  'Q5ZY11': 'None',
#  'Q9RW45': 'None',
#  'Q82S11': 'None',
#  'O29167': 'None',
#  'Q6DWK3': 'None',
#  'O81226': 'None',
#  'Q9CP67': 'None',
#  '2J1A': 'None',
#  'O96507': 'None',
#  'O69275': 'None',
#  'Q97SQ7': 'None',
#  '2J6G': 'None',
#  'Q8DGS1': 'None',
#  'Q6QPJ4': 'None',
#  '2J8K': 'None',
#  '2JEQ': 'None',
#  '2JFR': 'None',
#  '2JFS': 'None',
#  '2JFT': 'None',
#  '2JIC': 'None',
#  '2JJL': 'None',
#  '2JJQ': 'None',
#  '2JL1': 'None',
#  '2JLQ': 'None',
#  '2JLS': 'None',
#  '970820': 'None',
#  '462718': 'None',
#  'Q9KCS7': 'None',
#  'Q8ZM67': 'None',
#  'Q832L1': 'None',
#  'Q6NIF5': 'None',
#  'Q7MXB3': 'None',
#  'Q837C3': 'None',
#  'Q8NLC1': 'None',
#  'Q2BVV3': 'None',
#  'Q0TU05': 'None',
#  'Q8UE86': 'None',
#  'Q833I7': 'None',
#  'Q5HCZ0': 'None',
#  'Q3M5Q1': 'None',
#  'Q9I6M1': 'None',
#  'Q8NQ14': 'None',
#  'Q8UD01': 'None',
#  'Q5CYG0': 'None',
#  'Q5PY49': 'None',
#  'Q8UDV3': 'None',
#  'Q913Z3': 'None',
#  'Q7V6D4': 'None',
#  'O61442': 'None',
#  'Q9EWH2': 'None',
#  'Q8GCC7': 'None',
#  'O10693': 'None',
#  'Q9KXS8': 'None',
#  'Q8UEU8': 'None',
#  'Q8IJ70': 'None',
#  'Q13PB7': 'None',
#  'Q89NG0': 'None',
#  'Q58855': 'None',
#  'Q5UP71': 'None',
#  'O33853': 'None',
#  'Q886T9': 'None',
#  'Q9RVG4': 'None',
#  'P14894': 'None',
#  'P81364': 'None',
#  'Q9UYR9': 'None',
#  'Q3M362': 'None',
#  'Q3D8N4': 'None',
#  'Q831R3': 'None',
#  'Q87WS9': 'None',
#  'Q88YI3': 'None',
#  'Q5KZF0': 'None',
#  'Q9WYC6': 'None',
#  'Q91HI9': 'None',
#  'P43311': 'None',
#  'Q6FJS2': 'None',
#  'Q6NGV8': 'None',
#  'Q40316': 'None',
#  '2P4O': 'None',
#  'Q5SKQ2': 'None',
#  'Q8FED2': 'None',
#  'Q9X1X9': 'None',
#  'Q8IB03': 'None',
#  'Q81IL5': 'None',
#  'O58461': 'None',
#  'Q8G4D5': 'None',
#  'Q6WIF3': 'None',
#  'Q5KYB2': 'None',
#  'Q8DYC0': 'None',
#  'Q5KYY8': 'None',
#  'Q5SKB1': 'None',
#  'Q5QL47': 'None',
#  'A1IIJ1': 'None',
#  'Q8R9P5': 'None',
#  'Q82VN8': 'None',
#  'Q7VXB3': 'None',
#  'Q6ARP5': 'None',
#  'A5KE01': 'None',
#  'Q48JX0': 'None',
#  'O30288': 'None',
#  'O58715': 'None',
#  'A3FQA7': 'None',
#  'Q8IEL9': 'None',
#  'Q7YTF7': 'None',
#  'Q41GJ8': 'None',
#  'Q4FU81': 'None',
#  'Q703G9': 'None',
#  'Q8UJB9': 'None',
#  'A3FQ68': 'None',
#  'P31243': 'None',
#  'Q8CTE2': 'None',
#  'Q1RXH4': 'None',
#  'Q1EM40': 'None',
#  'P27652': 'None',
#  'O76977': 'None',
#  'Q38BV6': 'None',
#  'Q2XSL7': 'None',
#  '2PVU': 'None',
#  'Q7RP52': 'None',
#  'P05769': 'None',
#  'Q1GXX6': 'None',
#  'Q9EWE9': 'None',
#  'O29668': 'None',
#  'O97241': 'None',
#  'Q470Y2': 'None',
#  'Q9P172': 'None',
#  '2Q1V': 'None',
#  'Q9NPY5': 'None',
#  'Q8DX25': 'None',
#  '2Q8W': 'None',
#  'Q41CU9': 'None',
#  'A3D7B7': 'None',
#  'Q4KD17': 'None',
#  'Q93LY7': 'None',
#  'A0JVA7': 'None',
#  'Q8NQB1': 'None',
#  'Q9V2L3': 'None',
#  'P84854': 'None',
#  'Q81BF7': 'None',
#  'Q8XV73': 'None',
#  'Q87T87': 'None',
#  'Q8A6W9': 'None',
#  'Q9AF14': 'None',
#  'Q57U41': 'None',
#  'Q5CRJ8': 'None',
#  'Q6PJF1': 'None',
#  'Q67733': 'None',
#  'Q9K9M4': 'None',
#  'Q82KE3': 'None',
#  'Q8UIJ6': 'None',
#  'Q11XA0': 'None',
#  'A5K709': 'None',
#  'Q03BX7': 'None',
#  'Q8NSR4': 'None',
#  'Q838Q5': 'None',
#  'Q7MX90': 'None',
#  'Q5LV76': 'None',
#  'Q6LFE0': 'None',
#  'Q1HBK6': 'None',
#  'A1T351': 'None',
#  'Q99SY4': 'None',
#  'Q74D90': 'None',
#  'Q5T3Z8': 'None',
#  'Q7KYS4': 'None',
#  'Q64XZ4': 'None',
#  'Q8KFI1': 'None',
#  'A1B060': 'None',
#  'Q11YS1': 'None',
#  'Q883G8': 'None',
#  'Q2ADF5': 'None',
#  'A2UG88': 'None',
#  'O58586': 'None',
#  'Q7KQK1': 'None',
#  'Q9RYD0': 'None',
#  'Q9RKT6': 'None',
#  'Q64V53': 'None',
#  'A3D5G6': 'None',
#  'Q0S3N9': 'None',
#  'Q97VU1': 'None',
#  'Q8UCH8': 'None',
#  'P07239': 'None',
#  'A4XF70': 'None',
#  'A0FW12': 'None',
#  'Q2G9F6': 'None',
#  'Q7YYW6': 'None',
#  'Q2BKU2': 'None',
#  'A0GG20': 'None',
#  '2RKH': 'None',
#  ...}

# %%
def get_genes(U, Uniprot_seqids): 
    gene_list = []
    gene_line_list = []
    Un_list = []
    blacklist = []
    df_gene = pd.DataFrame(columns = ["Uniprot_id", "Gene", "Gene (line)"])
    
    for i, un_id in tqdm.tqdm_notebook(enumerate(Uniprot_seqids)):
       
        if un_id.isdigit():
            continue
        
        if i in blacklist: 
            continue
                
        else:
            data = u.search(un_id, frmt="txt") 
  
            if not str(data).isdigit(): # If it is digit, then it is the code for an error

                flag = 0
                for line in data.split("\n"):
                    if line.startswith('GN'):
                        #flag = 1
  
                        if (line.split()[1][0:5] == 'Name=') and flag == 0:

                            gene_name = line.split()[1][5:len(line.split()[1])]
                            if gene_name[-1] == ";":
                                gene_name = gene_name[0:len(gene_name)-1]
                            gene_list.append(gene_name)
                            gene_line_list.append(line)
                            Un_list.append(un_id)
                            flag = 1
                            continue
                        continue

            else:
                continue
            
        if (i+1) % 1000 == 0 :
            print("Iteration " + str(i+1) + ", len(gene_list) = " + str(len(gene_list)))
        
    
    return df, gene_list, gene_line_list, Un_list

# %%
u = UniProt(verbose=False)
df_gene, gene_list, gene_line_list, un_list = get_genes(u, list(dict_succ.values()))
# Out:
# C:\Users\alexh\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
df_ = pd.DataFrame(list(zip(list(dict_succ.keys()), list(dict_succ.values()), gene_list)), columns=['Uniprot_id_old', 'Uniprot_id_valid',  "Gene"])
display(df_)

df_.to_csv('genes_to_update.csv')
# Out:
#     Uniprot_id_old Uniprot_id_valid   Gene
# 0           P24991           P0AEG4   dsbA
# 1           P24930           P0C918    rus
# 2           P06128           P0AG82   pstS
# 3           P09097           P0AES4   gyrA
# 4           P06982           P0AES6   gyrB
# ..             ...              ...    ...
# 191         Q9FH83           P0DKH5   pknA
# 192         P62204           P0DP26  Calm1
# 193         P72056           P9WJF1    cya
# 194         Q07702           P9WG47   bipA
# 195         P0A4Z8           P9WPX3   amy1
#
# [196 rows x 3 columns]

# %%
gene_list
# Out:
# ['dsbA',
#  'rus',
#  'pstS',
#  'gyrA',
#  'gyrB',
#  'speC',
#  'malE',
#  'thyA1',
#  'thyA',
#  'dtxR',
#  'map',
#  'plc',
#  'celC',
#  'celA',
#  'SULT1A3',
#  'linB',
#  'inlB',
#  'CTS1',
#  'folA',
#  'mog',
#  'pdxH',
#  'fbpC',
#  'sucB',
#  'fucA',
#  'gpmA',
#  'cyp51',
#  'SAP2',
#  'tufA',
#  'rlmE',
#  'inhA',
#  'sodC',
#  'tufA',
#  'folP1',
#  'fbpB',
#  'PGA4',
#  'glpF',
#  'recA',
#  'tmk',
#  'MB',
#  'mglB',
#  'ino1',
#  'argB',
#  'fbaA',
#  'hisG',
#  'dacA',
#  'HSPA1A',
#  'C4A',
#  'trmI',
#  'leuB',
#  'tesA',
#  'ppiA',
#  'pelA',
#  'yciO',
#  'purA',
#  'cmaA2',
#  'aroK',
#  'def',
#  'MB',
#  'dut',
#  'cyp121',
#  'aphA',
#  'N',
#  'phzD2',
#  'hisG',
#  'ygfZ',
#  'msrA',
#  'inlA',
#  'pknB',
#  'bla',
#  'yibA',
#  'mshD',
#  'pfo',
#  'potD',
#  'sodC',
#  'sipA',
#  'purE',
#  'ompA',
#  'rmpM',
#  'glnL',
#  'lcrV',
#  'proX',
#  'rnhA',
#  'narL',
#  'pelL',
#  'pknD',
#  'gmk',
#  'pdtaR',
#  'ppa',
#  'ethR',
#  'coaD',
#  'dsbC',
#  'cyp51',
#  'ptpA',
#  'citE',
#  'dps',
#  'yggS',
#  'eda',
#  'sspA',
#  'glnH',
#  'tyrS',
#  'frr',
#  'metK',
#  'tpx',
#  'map',
#  'cya',
#  'mtcA2',
#  'livJ',
#  'mtnN',
#  'CSH1',
#  'desA2',
#  'pgk',
#  'aroC',
#  'rnc',
#  'panC',
#  'ospA',
#  'aroA',
#  'lppX',
#  'nagD',
#  'fprA',
#  'lat',
#  'PPIA',
#  'HSPA1A',
#  'embR',
#  'blaC',
#  'coaA',
#  'SAP3',
#  'cpdA',
#  'mbtI',
#  'ligD',
#  'gltX',
#  'prcB',
#  'dhaA',
#  'regX3',
#  'fcoT',
#  'adoK',
#  'EEF1AKMT4',
#  'cysK1',
#  'fabD',
#  'glmU',
#  'M',
#  'UBB',
#  'kasA',
#  'cyp124',
#  'cyp125',
#  'cyp142',
#  'priA',
#  'pdtaS',
#  'pth',
#  'ung',
#  'mamA',
#  'ospA',
#  'botA',
#  'cbh1',
#  'blaC',
#  'aiiA',
#  'gpgS',
#  'def',
#  'fadD28',
#  'nrdB',
#  'fba',
#  'rpfB',
#  'radA',
#  'cfaB',
#  'botA',
#  'dapF',
#  'gcvH',
#  'ilvE',
#  'sseA',
#  'gyrB',
#  'groEL1',
#  'cfp32',
#  'ripB',
#  'embC',
#  'ispE',
#  'trpC',
#  'eis',
#  'fadD13',
#  'asd',
#  'clpC1',
#  'ogt',
#  'RRS1',
#  'Calm1',
#  'dprE1',
#  'gyrA',
#  'ask',
#  'hisB',
#  'php',
#  'carD',
#  'aroQ',
#  'rsmE',
#  'mtc28',
#  'pknA',
#  'Calm1',
#  'cya',
#  'bipA',
#  'amy1']

# %%
# несоответсвие!!!!!!!!!!!!!!!!!!!! переписать скрипт через парсинг html

# %%
url = 'https://www.uniprot.org/uniprot/P24991'
resp = req.get(url)
 
soup = BeautifulSoup(resp.text, 'html.parser')

# %%
html_txt = soup.prettify()
data = html_txt.split('\n')
for i, line in enumerate(data):
    if 'content-gene' in line:
        break
        
#gene = str.strip(data[i+2])

# %%
soup.find_all('fa')
# Out:
# []

# %%
def find_gene_html(acc):    
    
    flag = False
    na = 'N/A'
    url = 'https://www.uniprot.org/uniprot/' + acc
    resp = req.get(url)
 
    soup = BeautifulSoup(resp.text, 'html.parser')
    
    html_txt = soup.prettify()
    data = html_txt.split('\n')
    for i, line in enumerate(data):
        if 'content-gene' in line:
            flag = True
            break
        
    if flag:
        gene = str.strip(data[i+2])
    else:
        gene = na
        
    return gene

# %%
gene_new_dict = {}

for i, acc in tqdm.tqdm_notebook(enumerate(uniprot_seqids)):
    if acc not in uniprot_genes:
        
        if acc in old_id_list:
            
            index = old_id_list.index(acc)
            acc_valid = new_id_list[index]
            
            gene_new_dict[acc] = find_gene_html(acc_valid)
        
        else:
            
            new_gene = find_gene_html(acc) 
            
            if (new_gene == 'N/A'):
                gene_new_dict[acc] = ''
            else:
                gene_new_dict[acc] = new_gene
# Out:
# C:\Users\alexh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
len(gene_new_dict)
# Out:
# 4073

# %%
k = 0
k_na = 0
k_none = 0
gene_list_towrite = {}

for key, value in gene_new_dict.items():
    if value == '':
        k_none += 1
    else:
        gene_list_towrite[key] = value

# %%
len(gene_list_towrite)
# Out:
# 2357

# %%
gene_list_towrite
# Out:
# {'P06492': 'UL48',
#  'P00969': '1.3',
#  'P24991': 'dsbA',
#  'P24930': 'rus',
#  'P06128': 'pstS',
#  'P09097': 'gyrA',
#  'P06982': 'gyrB',
#  'P13380': 'speC',
#  'P02928': 'malE',
#  'P42326': 'thyA1',
#  'P38197': 'YBL036C',
#  'P00470': 'thyA',
#  'P33120': 'dtxR',
#  'P07906': 'map',
#  'P15310': 'plc',
#  'P07985': 'celC',
#  'P04955': 'celA',
#  'P50224': 'SULT1A3',
#  'P80561': 'SGR_5809',
#  'P03692': '4',
#  'P51698': 'linB',
#  'P11922': 'YPTB1668',
#  'P25147': 'inlB',
#  'P54196': 'CTS1',
#  'P0A546': 'folA',
#  'P28694': 'mog',
#  'P28225': 'pdxH',
#  'P0A4V4': 'fbpC',
#  'Q58292': 'MJ0882',
#  'P07016': 'sucB',
#  'P11550': 'fucA',
#  'P31217': 'gpmA',
#  'P77901': 'cyp51',
#  'P28871': 'SAP2',
#  'P46076': 'AO090010000493',
#  'P02990': 'tufA',
#  'P28692': 'rlmE',
#  'O26253': 'MTH_150',
#  'O26255': 'MTH_152',
#  'P0A5Y6': 'inhA',
#  'P53635': 'sodC',
#  'P0A6N1': 'tufA',
#  'O51923': 'PF1739',
#  'P0A578': 'folP1',
#  'P31952': 'fbpB',
#  'Q58206': 'MJ0796',
#  'P00790': 'PGA4',
#  'P11244': 'glpF',
#  'P0A5U4': 'recA',
#  'Q8U3I1': 'PF0485',
#  'O05891': 'tmk',
#  'P02188': 'MB',
#  'P02927': 'mglB',
#  'P71703': 'ino1',
#  'Q56148': 'SVEN_4064',
#  'P11445': 'argB',
#  'Q9WXN1': 'TM_0024',
#  'P11604': 'fbaA',
#  'P10366': 'hisG',
#  'P04287': 'dacA',
#  'P08107': 'HSPA1A',
#  'O29562': 'AF_0696',
#  'P01028': 'C4A',
#  'O33253': 'trmI',
#  'P00351': 'leuB',
#  'P73797': 'slr1257',
#  'Q8ZUR7': 'PAE2646',
#  'O58727': 'PH0999',
#  'O58346': 'PH0612',
#  'Q84CU4': 'TTHA1819',
#  'P29679': 'tesA',
#  'O50082': 'PH1374',
#  'Q8L3C8': 'TthHC11_07190',
#  'P44882': 'HI_0817',
#  'P20752': 'ppiA',
#  'Q9WZS0': 'TM_0813',
#  'Q9WZD5': 'TM_0667',
#  'O04147': 'At4g18930',
#  'Q9X0M3': 'TM_1139',
#  'P29155': 'pelA',
#  'P45847': 'yciO',
#  'Q8U3L0': 'PF0456',
#  'Q9WYN0': 'TM_0399',
#  'P12283': 'purA',
#  'P11818': 'L5',
#  'P0A5P0': 'cmaA2',
#  'Q967M2': 'DHA2_112885',
#  'P0A4Z2': 'aroK',
#  'O67517': 'aq_1575',
#  'Q9F4L4': 'def',
#  'P02162': 'MB',
#  'Q9X1H9': 'TM_1468',
#  'O33199': 'MT1739',
#  'P0A552': 'dut',
#  'P17989': 'Fisuc_2961',
#  'O24970': 'HP_0162',
#  'P0A514': 'cyp121',
#  'Q8IEU2': 'PF3D7_1302100',
#  'P32697': 'aphA',
#  'Q01552': 'N',
#  'Q7DC80': 'phzD2',
#  'P60759': 'hisG',
#  'O13998': 'SPAC27E2.03c',
#  'Q9HIT9': 'Ta1238',
#  'Q04299': 'YMR087W',
#  'Q8TZN6': 'PF1951',
#  'Q9HIA7': 'Ta1434',
#  'Q9RV46': 'DR_1184',
#  'P39179': 'ygfZ',
#  'P0A5L0': 'msrA',
#  'Q9X0G9': 'TM_1080',
#  'Q9X0P2': 'TM_1158',
#  'Q9X1V6': 'TM_1621',
#  'Q9WZX8': 'TM_0875',
#  'Q9X033': 'TM_0935',
#  'Q9WZK7': 'TM_0748',
#  'Q9X0Q3': 'TM_1171',
#  'Q9WY13': 'TM_0166',
#  'P25146': 'inlA',
#  'P0A5S4': 'pknB',
#  'Q9KZR7': 'SCO2884',
#  'P14557': 'bla',
#  'P24172': 'yibA',
#  'O53831': 'mshD',
#  'Q9WXY0': 'TM_0126',
#  'O29759': 'AF_0491',
#  'P19995': 'pfo',
#  'P23861': 'potD',
#  'Q9X0G1': 'TM_1072',
#  'Q9X264': 'TM_1742',
#  'P0A608': 'sodC',
#  'Q56027': 'sipA',
#  'Q9HIB8': 'Ta1423',
#  'P47273': 'MG027',
#  'Q27679': 'LDHU3_26.0190',
#  'P09028': 'purE',
#  'P02934': 'ompA',
#  'P91020': 'C07D8.6',
#  'P38367': 'rmpM',
#  'O66665': 'aq_328',
#  'P06712': 'glnL',
#  'P21206': 'lcrV',
#  'P14177': 'proX',
#  'O53240': 'Rv2991',
#  'Q9HII6': 'Ta1353',
#  'P00647': 'rnhA',
#  'P10957': 'narL',
#  'Q9I4D4': 'PA1204',
#  'Q47473': 'pelL',
#  'O05871': 'pknD',
#  'Q8I4Y0': 'PF3D7_1245100',
#  'Q81L49': 'GBAA_4783',
#  'P74325': 'slr0953',
#  'P0A5I4': 'gmk',
#  'O06143': 'pdtaR',
#  'Q82ZQ3': 'EF_2996',
#  'Q8U2E3': 'PF0895',
#  'Q9RVK2': 'DR_1025',
#  'Q18946': 'CELE_D1054.8',
#  'Q8I3X4': 'PF3D7_0513300',
#  'O29280': 'AF_0982',
#  'P65746': 'ppa',
#  'P96222': 'ethR',
#  'Q58588': 'MJ1187',
#  'P75429': 'MPN_349',
#  'O61793': 'CELE_R12E2.13',
#  'P75455': 'MPN_330',
#  'P0A530': 'coaD',
#  'P21892': 'dsbC',
#  'Q9YE16': 'APE_0754.1',
#  'Q5SKJ3': 'TTHA0650',
#  'Q08210': 'PFF0160c',
#  'Q9HIW7': 'Ta1209',
#  'P0A512': 'cyp51',
#  'P65716': 'ptpA',
#  'P75430': 'MPN_348',
#  'O06162': 'citE',
#  'Q5SJI0': 'TTHA1028',
#  'Q9FXT4': 'Os10g0493600',
#  'P10186': 'UL2',
#  'O59595': 'PH1932',
#  'O58335': 'PH0582',
#  'O59257': 'PH1591',
#  'O57758': 'PH0022',
#  'Q9X1M1': 'TM_1535',
#  'Q53WB3': 'TTHB049',
#  'O59580': 'PH1917',
#  'O57770': 'PH0010',
#  'Q746L8': 'TT_P0035',
#  'O57975': 'PH0236',
#  'O57823': 'PH0099',
#  'Q5SLE6': 'TTHA0347',
#  'Q8VP75': 'dps',
#  'O58104': 'PH0366',
#  'Q9WXV1': 'TM_0096',
#  'Q9X0D8': 'TM_1048',
#  'O28751': 'AF_1521',
#  'Q9KPK1': 'VC_2366',
#  'Q9ABV9': 'CC_0111',
#  'Q8YWS4': 'alr1529',
#  'Q8YY48': 'alr1004',
#  'Q9WZL1': 'TM_0752',
#  'Q9X1L2': 'TM_1526',
#  'Q9X274': 'TM_1752',
#  'Q8U3S5': 'PF0380',
#  'Q9WYP6': 'TM_0415',
#  'Q9X1J4': 'TM_1506',
#  'Q9X1S2': 'TM_1586',
#  'Q9WZI2': 'TM_0723',
#  'O30133': 'AF_0103',
#  'Q8A1L2': 'BT_3649',
#  'Q9WYA0': 'TM_0262',
#  'Q9WZ14': 'TM_0544',
#  'Q9X1W6': 'TM_1631',
#  'Q9RW27': 'DR_0842',
#  'Q9HUY3': 'PA4827',
#  'P52054': 'yggS',
#  'O28590': 'AF_1683',
#  'O28951': 'AF_1318',
#  'P10177': 'eda',
#  'Q5SKH2': 'TTHA0671',
#  'P04188': 'sspA',
#  'Q5SIB2': 'TTHA1462',
#  'P10344': 'glnH',
#  'Q72LK7': 'TT_C0052',
#  'P00951': 'tyrS',
#  'P66734': 'frr',
#  'O59452': 'PH1788',
#  'Q9V2W5': 'A3L09_04975',
#  'Q9KB30': 'BH2105',
#  'O58261': 'PH0525',
#  'Q53W84': 'TTHB078',
#  'O57946': 'PH0207',
#  'Q53W82': 'TTHB080',
#  'O58216': 'PH0459',
#  'Q81HJ5': 'BC_0811',
#  'Q949P3': 'At2g17340',
#  'Q9AAV3': 'CC_0490',
#  'Q8U1K9': 'PF1197',
#  'Q816R4': 'BC_4754',
#  'Q8YSC4': 'alr3165',
#  'Q8KCB6': 'CT1508',
#  'Q9KQU9': 'VC_1899',
#  'Q9ASX2': 'At1g07440',
#  'Q8ZVK6': 'PAE2237',
#  'P04384': 'metK',
#  'Q4Q7M2': 'LMJF_30_0810',
#  'P66952': 'tpx',
#  'Q9HVP2': 'PA4535',
#  'P0A5J2': 'map',
#  'Q4Q7A6': 'LMJF_30_1890',
#  'P72583': 'sll0558',
#  'O28724': 'AF_1548',
#  'O28835': 'AF_1437',
#  'Q97GJ5': 'CA_C2371',
#  'Q9KQN0': 'VC_1968',
#  'Q7VXW9': 'BP1605',
#  'Q9HJW1': 'Ta0852',
#  'Q8U4C0': 'PF0168',
#  'Q9KS51': 'VC_1409',
#  'Q8U046': 'PF1771',
#  'Q49434': 'MG438',
#  'O67322': 'aq_1292',
#  'O30820': 'cya',
#  'O53573': 'mtcA2',
#  'Q8A090': 'BT_4131',
#  'Q5SL73': 'TTHA0420',
#  'O28840': 'AF_1432',
#  'Q8Y8Q1': 'lmo0845',
#  'Q99ZW4': 'SPy_1043',
#  'Q9HJ28': 'Ta1145',
#  'P96830': 'MT0162',
#  'Q81EW9': 'BC_1844',
#  'Q839J6': 'EF_0169',
#  'Q4D3U8': 'Tc00.1047053505945.20',
#  'Q9KQJ1': 'VC_2007',
#  'O29883': 'AF_0364',
#  'P02917': 'livJ',
#  'P59641': '1a',
#  'Q9HYR3': 'PA3332',
#  'P24247': 'mtnN',
#  'Q97XQ5': 'SSO1655',
#  'Q8I2M1': 'PF3D7_0928900',
#  'Q837R1': 'EF_0770',
#  'Q9I4A4': 'PA1234',
#  'Q9X0C0': 'TM_1030',
#  'P01243': 'CSH1',
#  'Q7RSH5': 'PY00382',
#  'O53442': 'desA2',
#  'Q3Y185': 'HMPREF0351_12555',
#  'Q87HD3': 'VPA1032',
#  'Q7MVG4': 'PG_1100',
#  'O28262': 'AF_2017',
#  'P11665': 'pgk',
#  'Q9YEQ6': 'APE_0525.1',
#  'Q81H03': 'BC_1024',
#  'P63611': 'aroC',
#  'Q9I509': 'PA0949',
#  'O30200': 'AF_0035',
#  'Q9LZX1': 'At5g01750',
#  'Q4DSA0': 'Tc00.1047053507031.90',
#  'P66666': 'rnc',
#  'O64527': 'At1g79260',
#  'Q8ZJX7': 'STM4540',
#  'Q8DQK6': 'spr0628',
#  'P0A5R0': 'panC',
#  'Q57622': 'MJ0158',
#  'P14013': 'ospA',
#  'Q7MW33': 'PG_0816',
#  'Q7RPE4': 'PY01515',
#  'Q4Q067': 'LMJF_36_6870',
#  'O24984': 'HP_0184',
#  'Q7R866': 'PY07357',
#  'Q9I476': 'PA1268',
#  'Q58193': 'MJ0783',
#  'O29285': 'AF_0977',
#  'O29141': 'AF_1124',
#  'Q4QH86': 'LMJF_10_1260',
#  'Q7RRM6': 'PY00693',
#  'Q8DUW5': 'SMU_776',
#  'Q98325': 'MC159L',
#  'Q7RB63': 'PY06285',
#  'Q5ZZB6': 'lpg0095',
#  'Q9K6P2': 'BH3686',
#  'P96398': 'MT0226',
#  'P22487': 'aroA',
#  'P0C6U8': '1a',
#  'P65306': 'lppX',
#  'Q6Q0L5': 'A197',
#  'Q9RWF4': 'DR_0715',
#  'Q57849': 'MJ0406',
#  'P15302': 'nagD',
#  'O05783': 'fprA',
#  'P63509': 'lat',
#  'Q03161': 'YMR099C',
#  'Q5SHI0': 'TTHA1750',
#  'Q5SKQ0': 'TTHA0593',
#  'Q5SJF5': 'TTHA1053',
#  'Q5SLC3': 'TTHA0370',
#  'Q5SMG9': 'TTHA1059',
#  'Q9YC08': 'APE_1443.1',
#  'P05092': 'PPIA',
#  'Q5SH92': 'TTHA1838',
#  'O57933': 'PH0194',
#  'Q4W9V8': 'AFUA_4G03560',
#  'Q5SLW4': 'TTHA0179',
#  'Q5SJQ7': 'TTHA0951',
#  'Q7W0A0': 'BP0250',
#  'P58502': 'TK1675',
#  'P95276': 'MT1988',
#  'O59282': 'PH1566',
#  'O59046': 'PH1320',
#  'Q5JQI4': 'HSPA1A',
#  'Q5SI78': 'TTHA1496',
#  'Q5L3S8': 'GK0065',
#  'Q59014': 'MJ1619',
#  'Q8A611': 'BT_2075',
#  'Q9X056': 'TM_0961',
#  'Q87UR7': 'PSPTO_5229',
#  'B2J9B4': 'Npun_R0659',
#  'Q6FF54': 'ACIAD0353',
#  'Q9X0A5': 'TM_1012',
#  'Q830Y8': 'EF_2626',
#  'Q8IJH3': 'PF3D7_1023200',
#  'Q9KQV9': 'VC_1889',
#  'P66799': 'embR',
#  'Q8A8B0': 'BT_1257',
#  'Q9HKL4': 'Ta0583',
#  'B0RM26': 'XCCB100_0282',
#  'Q9X0D9': 'TM_1049',
#  'O53827': 'Rv0813c',
#  'Q9HXQ8': 'PA3734',
#  'Q83883': 'ORF1',
#  'O29889': 'AF_0358',
#  'Q6NJA6': 'DIP0503',
#  'P64803': 'Rv1314c',
#  'Q7CXI0': 'Atu2258',
#  'Q5F581': 'NGO_2048',
#  'Q0S9X7': 'RHA1_ro03859',
#  'Q7MAW7': 'PG_0396',
#  'P0A5I6': 'blaC',
#  'Q9I2Q9': 'PA1836',
#  'P63810': 'coaA',
#  'Q7D0W3': 'Atu0702',
#  'Q9I4V0': 'PA1024',
#  'Q9K0T5': 'NMB0488',
#  'Q9WZM9': 'TM_0771',
#  'P44941': 'HI_0933',
#  'Q6NEA9': 'DIP2367',
#  'P16342': '1a',
#  'Q9KUL5': 'VC_0503',
#  'Q86SB2': 'PY17X_1306600',
#  'Q5SK45': 'TTHA0807',
#  'P43092': 'SAP3',
#  'Q9I5E5': 'PA0793',
#  'Q9KUP8': 'VC_0467',
#  'Q8EIU4': 'SO_0740',
#  'Q9A395': 'CC_3309',
#  'Q3M7N3': 'Ava_3396',
#  'Q8KBS5': 'CT1708',
#  'Q88R33': 'PP_0301',
#  'Q9X0V1': 'TM_1224',
#  'O59346': 'PH1655',
#  'Q7CX01': 'Atu2462',
#  'Q0SB06': 'RHA1_ro03477',
#  'Q9KFA8': 'BH0577',
#  'Q57K43': 'SCH_3013',
#  'Q7V4A7': 'PMT_2055',
#  'Q8P3K2': 'XCC4069',
#  'Q9X2E8': 'TM_1828',
#  'O06629': 'cpdA',
#  'Q8CJS4': 'SCO4940',
#  'Q6D668': 'ECA1819',
#  'Q7PP01': 'AgaP_AGAP006171',
#  'Q816V9': 'BC_4706',
#  'O28741': 'AF_1531',
#  'Q7MW92': 'PG_0744',
#  'Q97VZ7': 'SSO2453',
#  'Q7MWA6': 'PG_0725',
#  'Q7D785': 'mbtI',
#  'O25234': 'HP_0492',
#  'Q4FPZ7': 'Psyc_2064',
#  'Q9XA31': 'SCO3833',
#  'Q926X2': 'lin2918',
#  'Q837K0': 'EF_0837',
#  'Q5ZY11': 'lpg0564',
#  'Q9RW45': 'DR_0824',
#  'Q82S11': 'NE2553',
#  'P71571': 'ligD',
#  'O29167': 'AF_1098',
#  'Q9CP67': 'PM0188',
#  'Q8DGS1': 'tlr2243',
#  'P0A636': 'gltX',
#  'O33245': 'prcB',
#  'Q9KCS7': 'BH1492',
#  'Q8ZM67': 'STM3071',
#  'Q832L1': 'EF_2215',
#  'Q6NIF5': 'DIP0822',
#  'Q7MXB3': 'PG_0293',
#  'Q837C3': 'EF_0920',
#  'Q8NLC1': 'Cgl3021',
#  'Q833I7': 'EF_1965',
#  'Q3M5Q1': 'Ava_4081',
#  'Q50642': 'dhaA',
#  'Q9I6M1': 'PA0269',
#  'Q8NQ14': 'Cgl1640',
#  'Q5CYG0': 'cgd7_2470',
#  'Q7V6D4': 'PMT_1231',
#  'Q9EWH2': 'SCO4977',
#  'Q9KXS8': 'SCO4313',
#  'Q8UEU8': 'Atu1656',
#  'Q8IJ70': 'PF3D7_1033900',
#  'Q13PB7': 'Bxe_B1897',
#  'Q89NG0': 'blr3880',
#  'Q11156': 'regX3',
#  'Q58855': 'MJ1460',
#  'Q5UP71': 'MIMI_L605',
#  'Q886T9': 'PSPTO_1487',
#  'Q9RVG4': 'DR_1065',
#  'Q9UYR9': 'PYRAB14380',
#  'Q3M362': 'Ava_4977',
#  'Q831R3': 'EF_2437',
#  'Q87WS9': 'PSPTO_4464',
#  'Q5KZF0': 'GK1651',
#  'Q9WYC6': 'TM_0290',
#  'P33064': 'H1L',
#  'Q6FJS2': 'CAGL0M04037g',
#  'Q6NGV8': 'DIP1392',
#  'Q5SKQ2': 'TTHA0591',
#  'Q9X1X9': 'TM_1646',
#  'Q8IB03': 'PF3D7_0816600',
#  'Q81IL5': 'BC_0371',
#  'O58461': 'PH0730',
#  'Q8G4D5': 'BL1453',
#  'Q5KYB2': 'GK2039',
#  'Q8DYC0': 'SAG1567',
#  'Q5KYY8': 'GK1813',
#  'Q5SKB1': 'TTHA0737',
#  'Q5QL47': 'GKP20',
#  'Q8R9P5': 'TTE1560',
#  'P64685': 'fcoT',
#  'Q82VN8': 'NE1028',
#  'Q7VXB3': 'BP1887',
#  'Q6ARP5': 'DP0251',
#  'A5KE01': 'PVX_111245',
#  'Q48JX0': 'PSPPH_2088',
#  'O30288': 'AF_2382',
#  'O58715': 'PH0987',
#  'P83734': 'adoK',
#  'A3FQA7': 'cgd2_4120',
#  'Q8IEL9': 'PF3D7_1309600',
#  'Q7YTF7': 'PF3D7_0213400',
#  'Q4FU81': 'Psyc_0566',
#  'A3FQ68': 'cgd2_1660',
#  'Q1EM40': 'mes0020',
#  'Q38BV6': 'Tb10.70.4740',
#  'Q7RP52': 'PY01609',
#  'Q9BRZ8': 'EEF1AKMT4',
#  'Q1GXX6': 'Mfla_2648',
#  'Q9EWE9': 'SCO4942',
#  'O29668': 'AF_0587',
#  'O97241': 'PF3D7_0305700',
#  'Q470Y2': 'Reut_A1686',
#  'P0A534': 'cysK1',
#  'Q8DX25': 'SAG2033',
#  'A3D7B7': 'Sbal_3149',
#  'Q4KD17': 'PFL_2759',
#  'P63458': 'fabD',
#  'A0JVA7': 'Arth_1583',
#  'Q8NQB1': 'Cgl1527',
#  'Q9V2L3': 'PAB2304',
#  'Q81BF7': 'BC_3205',
#  'Q8XV73': 'RSc2958',
#  'Q87T87': 'VP0183',
#  'Q8A6W9': 'BT_1757',
#  'Q9AF14': 'BS585_17370',
#  'Q57U41': 'Tb927.8.8040',
#  'Q5CRJ8': 'cgd5_2510',
#  'P96382': 'glmU',
#  'Q9K9M4': 'BH2621',
#  'Q82KE3': 'SAVERM_2460',
#  'A5K709': 'PVX_099895',
#  'Q03BX7': 'LSEI_0440',
#  'Q8NSR4': 'Cgl0604',
#  'Q838Q5': 'EF_0381',
#  'Q7MX90': 'PG_0320',
#  'Q5LV76': 'SPO0826',
#  'A1T351': 'Mvan_0763',
#  'Q74D90': 'GSU1429',
#  'Q64XZ4': 'BF0881',
#  'Q8KFI1': 'CT0345',
#  'A1B060': 'Pden_0792',
#  'Q883G8': 'PSPTO_2395',
#  'O58586': 'PH0856',
#  'Q7KQK1': 'PF3D7_1219700',
#  'Q9RYD0': 'DR_0020',
#  'Q9RKT6': 'SCO6256',
#  'Q64V53': 'BF1877',
#  'A3D5G6': 'Sbal_2486',
#  'Q0S3N9': 'RHA1_ro06070',
#  'Q97VU1': 'SSO2518',
#  'P07239': 'H1L',
#  'A4XF70': 'Saro_3722',
#  'Q2G9F6': 'Saro_1072',
#  'Q9CCZ4': 'ML2640',
#  'Q8TLY9': 'MA_2883',
#  'Q4WCU5': 'AFUA_6G02460',
#  'Q8XNK4': 'CPE0329',
#  'Q9JZ41': 'NMB1309',
#  'P03419': 'M',
#  'Q8SU65': 'ECU11_0510',
#  'Q97VZ8': 'SSO2452',
#  'Q9L6G4': 'DT376_07370',
#  'Q8DV82': 'SMU_623c',
#  'P62988': 'UBB',
#  'B2IUW9': 'Npun_R6073',
#  'A3FQ16': 'cgd3_920',
#  'P63454': 'kasA',
#  'Q5XAZ8': 'M6_Spy1280',
#  'P0A516': 'cyp124',
#  'A3DJ30': 'Cthe_2760',
#  'O59485': 'PH1821',
#  'Q9HVG0': 'PA4631',
#  'Q9L074': 'SCO2780',
#  'P63709': 'cyp125',
#  'Q59X88': 'CAALFM_CR08050CA',
#  'Q8DI03': 'tlr1789',
#  'Q8DI95': 'tll1695',
#  'O30295': 'AF_2375',
#  'O53563': 'cyp142',
#  'P73600': 'sll1785',
#  'Q9X0S8': 'TM_1201',
#  'A3DCJ4': 'Cthe_0435',
#  'Q8PYK9': 'MM_0852',
#  'Q2CEE3': 'OG2516_04129',
#  'A6G7B1': 'PPSIR1_08671',
#  'Q584S0': 'Tb927.6.2360',
#  'Q72HW2': 'TT_C1370',
#  'Q9HWP4': 'PA4137',
#  'Q73KE9': 'TDE_2269',
#  'P60578': 'priA',
#  'A3DHG6': 'Cthe_2193',
#  'Q7NXD4': 'CV_1693',
#  'Q4K5L5': 'PFL_5400',
#  'A9CFJ9': 'Atu3701',
#  'Q9RS96': 'DR_2231',
#  'Q97UU7': 'SSO2896',
#  'O05846': 'pdtaS',
#  'Q5F9M1': 'NGO_0372',
#  'A0R2V4': 'MSMEG_5246',
#  'P53929': 'YNL108C',
#  'Q8GNN6': 'BUE81_04000',
#  'Q53W68': 'TTHB094',
#  'Q5SJY9': 'TTHA0863',
#  'O67769': 'aq_1956',
#  'Q5SMG8': 'TTHA1060',
#  'Q53W90': 'TTHB072',
#  'Q9YBB1': 'APE_1686.1',
#  'O58581': 'PH0851',
#  'Q5SJP8': 'TTHA0960',
#  'Q9WYQ2': 'TM_0421',
#  'O59416': 'PH1780',
#  'Q5SJJ6': 'TTHA1012',
#  'Q5SHN1': 'TTHA1699',
#  'Q5SHD1': 'TTHA1799',
#  'Q72HN8': 'TT_C1448',
#  'Q5JII7': 'TK1993',
#  'Q836L2': 'EF_1099',
#  'P65865': 'pth',
#  'Q988D0': 'mlr6791',
#  'Q9RVU2': 'DR_0930',
#  'Q5SIL0': 'TTHA1359',
#  'Q9FBX0': 'SCO7815',
#  'Q5SIE5': 'TTHA1429',
#  'Q3IGF7': 'PSHAa1477',
#  'P71872': 'MT3632',
#  'Q5SKW0': 'TTHA0533',
#  'O58925': 'PH1171',
#  'Q53WA6': 'TTHB056',
#  'Q9X180': 'TM_1359',
#  'Q9WXQ8': 'TM_0051',
#  'Q5UQ00': 'MIMI_L315',
#  'P67071': 'ung',
#  'Q8ZUN8': 'PAE2689',
#  'Q5SK18': 'TTHA0834',
#  'Q5ZUA2': 'lpg1905',
#  'Q5SLS3': 'TTHA0220',
#  'Q988B9': 'mlr6805',
#  'Q9F377': 'SCO4411',
#  'Q988D3': 'mlr6788',
#  'Q8E372': 'gbs1889',
#  'Q12UN6': 'Mbur_1960',
#  'Q50224': 'mamA',
#  'Q4JA33': 'Saci_0986',
#  'O53318': 'Rv3168',
#  'P0C926': 'ospA',
#  'Q8ZWA8': 'PAE1888',
#  'Q9YCJ0': 'APE_1267.1',
#  'Q53W63': 'TTHB099',
#  'Q8DUW0': 'SMU_781',
#  'Q2SZE4': 'BTH_I1158',
#  'Q9I187': 'PA2393',
#  'Q929T5': 'lin2189',
#  'P96405': 'MT0233',
#  'Q81BN2': 'BC_3120',
#  'Q92AN1': 'lin1889',
#  'A5KBP6': 'PVX_003920',
#  'P33324': 'YKL091C',
#  'Q46R99': 'Reut_B4987',
#  'Q97D74': 'CA_C3606',
#  'Q9HLN3': 'Ta0194',
#  'Q5CRC5': 'cgd5_3360',
#  'Q1GJN9': 'TM1040_0394',
#  'A3QGX4': 'Shew_2856',
#  'Q9KND6': 'VC_A0029',
#  'Q87Q63': 'VP1287',
#  'O59179': 'PH1510',
#  'Q0G7J9': 'FP2506_05986',
#  'Q9S1P1': 'SCO0250',
#  'Q9RVD0': 'DR_1099',
#  'Q816E8': 'BC_4913',
#  'A5HZZ9': 'botA',
#  'Q0I408': 'HS_1138',
#  'Q2G9T7': 'Saro_0941',
#  'Q83884': 'ORF2',
#  'Q882E2': 'PSPTO_2686',
#  'Q746K1': 'TT_P0052',
#  'Q8TYK3': 'MK0293',
#  'Q9HJZ0': 'Ta0821',
#  'P40363': 'YJL068C',
#  'Q46MU0': 'Reut_C6226',
#  'Q97BR6': 'TVG0375766',
#  'Q11C84': 'Meso_3622',
#  'Q1GJR2': 'TM1040_0371',
#  'A6L094': 'BVU_1420',
#  'Q8U2Y3': 'PF0695',
#  'Q55813': 'slr0095',
#  'O26735': 'MTH_639',
#  'Q9FBN7': 'SCO5041',
#  'Q73BT6': 'BCE_1332',
#  'Q97JL1': 'CA_C1263',
#  'Q7W6R8': 'BPP2833',
#  'Q0I0Z6': 'HS_0128',
#  'P00725': 'cbh1',
#  'P0C5C1': 'blaC',
#  'Q5SLE7': 'TTHA0346',
#  'Q30Y26': 'Dde_2624',
#  'A4HFB4': 'LBRM_26_2630',
#  'Q5LLI5': 'SPOA0042',
#  'Q9X1D6': 'TM_1419',
#  'Q9X0Z6': 'TM_1269',
#  'Q28QQ5': 'Jann_2040',
#  'Q834X5': 'EF_1502',
#  'Q5LTF6': 'SPO1458',
#  'Q2G812': 'Saro_1571',
#  'Q73WU1': 'MAP_2569c',
#  'Q41372': 'SOVF_195660',
#  'O96193': 'PF3D7_0211200',
#  'A9WCA2': 'Caur_0242',
#  'Q9WZ13': 'TM_0543',
#  'Q8A3X9': 'BT_2825',
#  'A1A3G9': 'BAD_1471',
#  'Q7W7N7': 'BPP2477',
#  'Q835X8': 'EF_1240',
#  'Q1GCP1': 'TM1040_2843',
#  'A4VVQ2': 'SSU05_1225',
#  'A1A237': 'BAD_0989',
#  'Q2LQ23': 'SYN_00638',
#  'A6THR5': 'KPN_04753',
#  'Q99R54': 'SAV2584',
#  'Q82ZB5': 'EF_3151',
#  'Q8DTX1': 'SMU_1196c',
#  'Q5LGR4': 'BF9343_0892',
#  'O58465': 'PH0734',
#  'A9CG77': 'Atu4201',
#  'Q72KM1': 'TT_C0312',
#  'Q9Z571': 'SCO5508',
#  'Q8U919': 'Atu3911',
#  'Q9X1Q6': 'TM_1570',
#  'O57768': 'PH0012',
#  'Q97U20': 'SSO3205',
#  'Q5F5I0': 'NGO_1945',
#  'Q74GS0': 'GSU0175',
#  'O29201': 'AF_1061',
#  'A0QTN8': 'MSMEG_1910',
#  'Q7B8B9': 'aiiA',
#  'Q89Z24': 'BT_4553',
#  'Q72ZL3': 'BCE_4655',
#  'Q6LY14': 'MMP1179',
#  'Q5LSK1': 'SPO1766',
#  'O29327': 'AF_0935',
#  'Q8NRD3': 'Cgl1119',
#  'Q927R6': 'lin2722',
#  'A7V5N4': 'BACUNI_02894',
#  'Q8YQS9': 'all3740',
#  'A6L7P8': 'BVU_4110',
#  'Q9HVJ6': 'PA4589',
#  'Q473P7': 'Reut_A1007',
#  'Q6N4Z3': 'RPA3190',
#  'Q13I95': 'Bxe_C0271',
#  'A1A2L3': 'BAD_1165',
#  'Q8KFZ1': 'CT0179',
#  'Q6N6X2': 'RPA2492',
#  'O05309': 'gpgS',
#  'Q9S2K6': 'SCO1997',
#  'P96275': 'def',
#  'Q73WB6': 'MAP_2744c',
#  'P96290': 'fadD28',
#  'A6L5C0': 'BVU_3255',
#  'Q88JU2': 'PP_2555',
#  'Q9KCP9': 'BH1520',
#  'Q1IZR6': 'Dgeo_0968',
#  'Q9YCF4': 'APE_1303.1',
#  'Q476C0': 'Reut_A0381',
#  'Q9KY99': 'SCO5003',
#  'A4XDU4': 'Saro_3860',
#  'Q9KLB0': 'VC_A0836',
#  'P96416': 'nrdB',
#  'Q5LT20': 'SPO1594',
#  'Q3M5R2': 'Ava_4070',
#  'Q30V07': 'Dde_3696',
#  'Q5LB02': 'BF9343_2939',
#  'Q2G4M1': 'Saro_2766',
#  'Q5LDN3': 'BF9343_1994',
#  'P67475': 'fba',
#  'Q5LN61': 'SPO3351',
#  'A5K9M4': 'PVX_080575',
#  'O05594': 'rpfB',
#  'Q8E044': 'SAG0892',
#  'Q81VC3': 'GBAA_0574',
#  'A4XEC0': 'Saro_3421',
#  'Q5Z3N8': 'NFA_1110',
#  'Q977P5': 'radA',
#  'Q8E1B4': 'SAG0446',
#  'Q8U2I7': 'PF0847',
#  'Q8Y8U8': 'lmo0794',
#  'Q609M8': 'MCA1204',
#  'Q881P0': 'PSPTO_2847',
#  'P0C6U2': '1a',
#  'Q396C9': 'Bcep18194_B1568',
#  'Q5SLW7': 'TTHA0176',
#  'Q03S37': 'LVIS_0842',
#  'P35774': 'L5',
#  'Q8A635': 'BT_2051',
#  'Q74FR4': 'GSU0542',
#  'Q97FM4': 'CA_C2707',
#  'Q0S658': 'RHA1_ro05197',
#  'A6KZB9': 'BVU_1092',
#  'Q73QT9': 'TDE_0354',
#  'Q5L9G5': 'BF9343_3481',
#  'Q5CYL9': 'cgd7_1840',
#  'Q5FLP2': 'LBA0497',
#  'Q8A3I2': 'BT_2972',
#  'Q73GA4': 'WD_1055',
#  'Q0S966': 'RHA1_ro04124',
#  'A1TZ69': 'Maqu_0942',
#  'Q47ME9': 'Tfu_2340',
#  'Q88PF6': 'PP_0894',
#  'P02971': 'cfaB',
#  'Q97V23': 'SSO2813',
#  'Q81SB1': 'GBAA_1754',
#  'Q2RPE2': 'Rru_A3208',
#  'Q1GD43': 'TM1040_2691',
#  'A9CJQ0': 'Atu0928',
#  'Q8A653': 'BT_2033',
#  'Q5E0B9': 'VF_A0457',
#  'Q6N3B2': 'RPA3782',
#  'Q082D2': 'Sfri_2037',
#  'Q8IM71': 'PF3D7_1401800',
#  'Q929G0': 'lin2316',
#  'Q8IJ72': 'PF3D7_1033700',
#  'Q5LN19': 'SPO3393',
#  'Q9WYS0': 'TM_0439',
#  'Q99ZN4': 'SPy_1154',
#  'Q9X1M7': 'TM_1541',
#  'Q8I608': 'PF3D7_1203700',
#  'Q5HCZ5': 'SACOL2570',
#  'P10845': 'botA',
#  'P63897': 'dapF',
#  'O26314': 'MTH_212',
#  'Q5LD59': 'BF9343_2170',
#  'Q8XGU5': 'STY1333',
#  'Q5LER3': 'BF9343_1606',
#  'Q8THK8': 'MA_4506',
#  'Q8A8Z5': 'BT_1022',
#  'A6KY15': 'BVU_0621',
#  'Q8X8S5': 'E3149_09050',
#  'Q97DC5': 'CA_C3553',
#  'A6L7P9': 'BVU_4111',
#  'A8BZ95': 'GL50803_008037',
#  'Q8EMJ9': 'OB2843',
#  'Q8A8V5': 'BT_1062',
#  'Q9RZH8': 'DR_C0006',
#  'Q3M3X1': 'Ava_4718',
#  'Q8A9F0': 'BT_0865',
#  'Q58026': 'MJ0609',
#  'Q82L35': 'SAVERM_2177',
#  'Q987B2': 'mll7127',
#  'Q8NR27': 'Cgl1237',
#  'Q93RV7': 'SCO1869',
#  'Q2G9S0': 'Saro_0958',
#  'Q58361': 'MJ0951',
#  'Q7CG15': 'YPO3991',
#  'Q8EED0': 'SO_2452',
#  'Q1GZM5': 'Mfla_2045',
#  'Q7N439': 'plu2515',
#  'O57810': 'PH0053',
#  'Q8Y4Z4': 'lmo2285',
#  'B2I5L9': 'XfasM23_1239',
#  'Q2LQE8': 'SYN_02576',
#  'O25318': 'HP_0596',
#  'Q7CZ24': 'Atu1522',
#  'B1YEL6': 'Exig_2736',
#  'A3QIY5': 'Shew_3567',
#  'Q28PN4': 'Jann_2411',
#  'Q5LQA4': 'SPO2589',
#  'Q81LQ0': 'GBAA_4562',
#  'Q9WZH4': 'TM_0715',
#  'Q9X207': 'TM_1679',
#  'Q180K0': 'CD630_33550',
#  'Q72FB2': 'DVU_0302',
#  'Q4KAG7': 'PFL_3664',
#  'Q749I7': 'GSU2755',
#  'Q9Y8R5': 'APE_2568.1',
#  'Q8A600': 'BT_2086',
#  'A6LB94': 'BDI_1195',
#  'Q8A605': 'BT_2081',
#  'Q74AQ6': 'GSU2296',
#  'Q39VV7': 'Gmet_1383',
#  'Q8AB42': 'BT_0269',
#  'B3LB24': 'PKNH_1303500',
#  'A4SIK7': 'ASA_0563',
#  'Q50607': 'gcvH',
#  'Q929S5': 'lin2199',
#  'Q5CZ29': 'cgd7_40',
#  'Q81TP2': 'GBAA_1228',
#  'Q81YZ2': 'GBAA_0485',
#  'A3D092': 'Sbal_0626',
#  'Q6HDF0': 'BT9727_4108',
#  'Q5LB10': 'BF9343_2931',
#  'Q5M3Z4': 'stu1215',
#  'Q6NF81': 'DIP2013',
#  'Q838Q8': 'EF_0377',
#  'Q8A0P1': 'BT_3980',
#  'Q8A1I2': 'BT_3679',
#  'Q10399': 'ilvE',
#  'Q04DI1': 'OEOE_1641',
#  'Q2RQC5': 'Rru_A2873',
#  'Q9ZN18': 'jhp_0042',
#  'Q9I0R8': 'PA2567',
#  'Q24QE6': 'DSY3957',
#  'P96888': 'sseA',
#  'Q8A2Z3': 'BT_3162',
#  'Q72GF3': 'TT_C1895',
#  'Q2RWX8': 'Rru_A0563',
#  'Q5ZUH0': 'lpg1828',
#  'A9CIH8': 'Atu1885',
#  'Q886S7': 'PSPTO_1499',
#  'Q5LTV6': 'SPO1306',
#  'A1S4A6': 'Sama_1005',
#  'Q92EH0': 'lin0490',
#  'Q87ID1': 'VPA0675',
#  'Q1WSH7': 'LSL_1347',
#  'Q95WL3': 'C3747_22g238',
#  'Q9KY22': 'SCO2368',
#  'Q5F8U0': 'NGO_0670',
#  'A3MUJ4': 'Pcal_0885',
#  'Q93J45': 'SCO3058',
#  'Q8IL32': 'PF3D7_1443900',
#  'Q5LA60': 'BF9343_3233',
#  'A3D842': 'Sbal_3428',
#  'Q74MS9': 'NEQ261',
#  'P0C5C5': 'gyrB',
#  'O58866': 'PH1139',
#  'A1U3W3': 'Maqu_2607',
#  'Q70LE6': 'ORF157',
#  'A1S420': 'Sama_0919',
#  'Q83DX0': 'CBU_0572',
#  'Q89YQ6': 'BT_4675',
#  'Q2LU76': 'SYN_02013',
#  'Q9HIZ7': 'Ta1179',
#  'A5N734': 'CKL_1073',
#  'O53924': 'MT1716',
#  'Q7CX36': 'Atu2422',
#  'Q8PYS1': 'MM_0789',
#  'C4M7X7': 'EHI_119490',
#  'Q8PZ75': 'MM_0619',
#  'Q48J46': 'PSPPH_2384',
#  'Q9X0E0': 'TM_1050',
#  'Q11B79': 'Meso_3979',
#  'Q9X9V5': 'SCO1917',
#  'Q46PQ5': 'Reut_B5534',
#  'Q8AB38': 'BT_0273',
#  'Q2GIS1': 'APH_1197',
#  'Q9PER7': 'XF_0961',
#  'A6L326': 'BVU_2431',
#  'C6KT68': 'PF3D7_0623200',
#  'C4LSE7': 'EHI_153650',
#  'O87364': 'BN1321_460004',
#  'Q92T58': 'SMc04130',
#  'Q584R4': 'Tb927.6.2420',
#  'Q5E4K9': 'VF_1542',
#  'A3DJ37': 'Cthe_2767',
#  'A6L054': 'BVU_1379',
#  'A6LF92': 'BDI_2637',
#  'Q8A045': 'BT_4176',
#  'O25709': 'HP_1076',
#  'Q1GYA6': 'Mfla_2516',
#  'Q97IW1': 'CA_C1529',
#  'Q6NGS1': 'DIP1437',
#  'O84677': 'CT_670',
#  'Q72CX3': 'DVU_1160',
#  'Q5LDX8': 'BF9343_1896',
#  'Q5F6Z8': 'NGO_1391',
#  'Q8TTZ5': 'MA_0280',
#  'O69639': 'Rv3671c',
#  'Q92DQ0': 'lin0763',
#  'O96142': 'PF3D7_0204500',
#  'O67998': 'TP_0453',
#  'Q8DW05': 'SMU_286',
#  'Q0I4G3': 'HS_1420',
#  'Q97H19': 'CA_C2195',
#  'Q8PU56': 'MM_2493',
#  'Q9X0Y1': 'TM_1254',
#  'A6L4E1': 'BVU_2916',
#  'O53782': 'MT0703',
#  'Q58622': 'MJ1225',
#  'Q5HF23': 'SACOL1801',
#  'Q9HV14': 'PA4794',
#  'A6LC72': 'BDI_1531',
#  'Q5L808': 'BF9343_4008',
#  'Q8A1X3': 'BT_3535',
#  'A6L7K2': 'BVU_4064',
#  'B2IY64': 'Npun_R6391',
#  'B7JBP8': 'AFE_1792',
#  'Q83DY0': 'CBU_0560',
#  'Q8P431': 'XCC3885',
#  'Q837J7': 'EF_0840',
#  'Q7CIK0': 'YPO2259',
#  'Q9XAL8': 'SCO6712',
#  'Q8ABC9': 'BT_0181',
#  'Q11034': 'Rv1364c',
#  'Q8EGN5': 'SO_1565',
#  'Q8A204': 'BT_3504',
#  'P40579': 'YIR035C',
#  'Q2GHD1': 'ECH_0332',
#  'C4ZCC6': 'EUBREC_2131',
#  'Q5LHN1': 'BF9343_0570',
#  'A6LDL3': 'BDI_2046',
#  'Q89YU3': 'BT_4638',
#  'P58495': 'lmo0363',
#  'C6A190': 'TSIB_0319',
#  'Q8DTU5': 'SMU_1228c',
#  'Q8DTG7': 'SMU_1377c',
#  'Q8DVQ8': 'SMU_412c',
#  'Q8DU45': 'SMU_1108c',
#  'A0RD96': 'BALH_1870',
#  'Q8DWL4': 'SMU_31',
#  'Q4DA54': 'Tc00.1047053507019.40',
#  'P0C6V5': '1a',
#  ...}

# %%
df_ = pd.DataFrame(list(zip(list(gene_list_towrite.keys()), list(gene_list_towrite.values()))), columns=['Uniprot_id_valid',  "Gene"])
display(df_)

df_.to_csv('genes_to_update.csv')
# Out:
#      Uniprot_id_valid           Gene
# 0              P06492           UL48
# 1              P00969            1.3
# 2              P24991           dsbA
# 3              P24930            rus
# 4              P06128           pstS
# ...               ...            ...
# 2352           G2R014  THITE_2112714
# 2353           B2UR60      Amuc_1119
# 2354           Q53W80        TTHB082
# 2355           C7PL61      Cpin_0907
# 2356           Q4QEW6   LMJF_16_0540
#
# [2357 rows x 2 columns]

# %%
k = 0

for i, acc in tqdm.tqdm_notebook(enumerate(uniprot_seqids)):
    if acc not in uniprot_genes:
        
        if acc in old_id_list:
            
            k += 1
        
        else:
            
            k += 1
# Out:
# C:\Users\alexh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
gene_full = {}

for i, acc in tqdm.tqdm_notebook(enumerate(uniprot_seqids)):
        
        if acc in old_id_list:
            
            index = old_id_list.index(acc)
            acc_valid = new_id_list[index]
            
            gene_full[acc] = find_gene_html(acc_valid)
        
        else:
            
            new_gene = find_gene_html(acc) 
            
            if (new_gene == 'N/A'):
                gene_full[acc] = ''
            else:
                gene_full[acc] = new_gene
# Out:
# C:\Users\alexh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     274             # sending a valid response.
# --> 275             raise RemoteDisconnected("Remote end closed connection without"
#     276                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     274             # sending a valid response.
# --> 275             raise RemoteDisconnected("Remote end closed connection without"
#     276                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-76-a60aeb29dedb> in <module>
#      12         else:
#      13
# ---> 14             new_gene = find_gene_html(acc)
#      15
#      16             if (new_gene == 'N/A'):
#
# <ipython-input-59-c9ee23b3d0a7> in find_gene_html(acc)
#       4     na = 'N/A'
#       5     url = 'https://www.uniprot.org/uniprot/' + acc
# ----> 6     resp = req.get(url)
#       7
#       8     soup = BeautifulSoup(resp.text, 'html.parser')
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(ChromeDriverManager().install())

acc = 'mb'
url = 'https://gnomad.broadinstitute.org/gene/' + acc + '?dataset=gnomad_r2_1'
xpath = '/html/body/div[1]/div/div/div[2]/div/div[5]/section/div[2]/button'
class_ = 'Button__BaseButton-sc-1eobygi-0 Button-sc-1eobygi-1 indcWT'
driver.get(url)
assert "gnomAD" in driver.title


driver.switch_to.default_content()
#content = driver.find_elements(By.CLASS_NAME , class_)
#button = driver.find_elements(By.XPATH, '//button')

#button[0].click()
#button[1].click()
assert "No results found." not in driver.page_source
driver.close()
# Out:
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\alexh\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-128-14cffa3f5eb7> in <module>
#      15
#      16 driver.switch_to.default_content()
# ---> 17 content = driver.find_elements(By.CLASS_NAME , class_)[0].click()
#      18 #button = driver.find_elements(By.XPATH, '//button')
#      19
#
# IndexError: list index out of range

# %%
content
# Out:
# []

# %%
'''
<
button type="button" 
class="Button__BaseButton-sc-1eobygi-0 Button-sc-1eobygi-1 indcWT"
>
Export variants to CSV
</button>

copy selector:

#root > div > div > div.Page-w7h773-0.TrackPage-sc-1kiz7uj-0.hADDWA > div > div:nth-child(5) > section > div:nth-child(2) > button


copy js path:

document.querySelector("#root > div > div > div.Page-w7h773-0.TrackPage-sc-1kiz7uj-0.hADDWA > div > div:nth-child(5) > section > div:nth-child(2) > button")


copy element:

<button type="button" class="Button__BaseButton-sc-1eobygi-0 Button-sc-1eobygi-1 indcWT">Export variants to CSV</button>
'''
